# %% [markdown]
# # Medical Text Summarization - Exploration Notebook
#
# This notebook demonstrates the medical text summarization system for research and educational purposes.
#
# **DISCLAIMER: This is a research demonstration project and is NOT intended for clinical use.**
